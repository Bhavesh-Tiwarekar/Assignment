# %% [markdown]
# #### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
"""
Answer:

a. Flask is a web framework that provides libraries to build lightweight web applications in python. It is developed by Armin Ronacher.
   It is based on WSGI toolkit and jinja2 template engine. Flask is considered as a micro framework.
b. Advantages of Flask framework:
    1. Flask is designed to be simple and straightforward. It is easy to learn and use for small and medium-sized projects.
    2. It provides a high level of flexibility where the developers are allowed to to use various libraries and tools as per their needs.
    3. Developers can add functionalities through Flask extensions or third-party libraries.
    4. It is a lightweight framework because flask is independent of external libraries and it gives a quick start for web development 
       having complex applications.


"""
# Out:
# '\nAnswer:\n\na. Flask is a web framework that provides libraries to build lightweight web applications in python. It is developed by Armin Ronacher.\n   It is based on WSGI toolkit and jinja2 template engine. Flask is considered as a micro framework.\nb. Advantages of Flask framework:\n    1. Flask is designed to be simple and straightforward. It is easy to learn and use for small and medium-sized projects.\n    2. It provides a high level of flexibility where the developers are allowed to to use various libraries and tools as per their needs.\n    3. Developers can add functionalities through Flask extensions or third-party libraries.\n    4. It is a lightweight framework because flask is independent of external libraries and it gives a quick start for web development \n       having complex applications.\n\n\n'

# %% [markdown]
# #### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
# Program to create a Flask application to display 'Hello World!!'.

from flask import Flask

app = Flask(__name__)

@app.route("/Q2_hello_world")
def hello_world():
    return "<h3>Hello World!!</h3>"

if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (3).png](attachment:48c7c6c6-ed8f-4068-81ca-d35a8ef7b16e.png)

# %% [markdown]
# #### Q3. What is App routing in Flask? Why do we use app routes?

# %%
"""
Answer:

1. App routing means mapping the URLs to a specific function that will handle the logic for that URL.
2. 'app.route()' decorator is used to bind a function to an URL path.
3. Following are the reasons to use app routes:
    a. Routes allow us to map specific URLs to corresponding python functions.
    b. It helps to navigate to different pages within the application.
    c. It promotes a structured way of organizing code and logic.
    d. It allows users to perform different actions based on the URLs they access.
    e. It helps in building RESTful APIs.
"""
# Out:
# "\nAnswer:\n\n1. App routing means mapping the URLs to a specific function that will handle the logic for that URL.\n2. 'app.route()' decorator is used to bind a function to an URL path.\n3. Following are the reasons to use app routes:\n    a. Routes allow us to map specific URLs to corresponding python functions.\n    b. It helps to navigate to different pages within the application.\n    c. It promotes a structured way of organizing code and logic.\n    d. It allows users to perform different actions based on the URLs they access.\n    e. It helps in building RESTful APIs.\n"

# %% [markdown]
# #### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# ##### Company Name: ABC Corporation
# ##### Location: India
# ##### Contact Detail: 999-999-9999
# #### Attach the screenshot of the output in Jupyter Notebook.

# %%
# Program to display welcome message and shoe company details

from flask import Flask

app = Flask(__name__)

# Route to display the welcome message
@app.route("/welcome")
def welcome():
    return "<h2>Welcome to ABC Corporation</h2>"

# Route to display the details
@app.route("/")
def company_details():
    return "Company Name: ABC Corporation <br> Location: India <br> Contact Detail: 999-999-9999"             

if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (4).png](attachment:edba030f-5317-4924-8ff4-464d65eea7e3.png)

# %% [markdown]
# ![image.png](attachment:d7568019-c420-4f26-8837-a72c68bae62e.png)

# %% [markdown]
# #### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %%
"""
Answer:

1. The 'url_for()' function is used for building a URL to the specific function dynamically.
2. Using the 'url_for()' function the user can avoid hardcoding URLs in the templates and codes.
3. Following is the python code to demonstrate working of 'url_for()':
"""

from flask import Flask, url_for

app = Flask(__name__)

@app.route("/home")
def home():
    return "Welcome to the home page"

@app.route("/about")
def about():
    return "This is About Page"

@app.route("/")
def index():
    home_url = url_for("home")
    about_url = url_for("about")
    return f"""
    <h2>Navigation</h2>
    <ul>
        <li><a href="{home_url}">Home</a></li>
        <li><a href="{about_url}">About</a></li>
    </ul>
    """

if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:b53be638-b72b-42e6-b361-9a36610f4f10.png)

# %% [markdown]
# ![image.png](attachment:c8873587-1094-429e-9a02-f5d81291c1e9.png)

# %% [markdown]
# ![image.png](attachment:2cc90f9b-f590-4e7e-81c5-829895e22d59.png)
